# %% [markdown]
# # Homework: Sonar signal classification
# In this workshop you will train a binary classification neural network to differentiate if sonar signals bounced against a metal cylinder or a rock.
#
# [Info of the data](https://archive.ics.uci.edu/ml/datasets/Connectionist+Bench+(Sonar,+Mines+vs.+Rocks))
#
# Goal: Get an accuracy higher than 0.80 in the validation set

# %% [markdown]
# ## Get the data from Google Drive

# %%
# Import libraries to interact with Google Drive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# Authenticate with your Google account to get access to the data
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Download data
download = drive.CreateFile({'id': '1rw5l3jCo2vlNc8NLrMk3KPZr6HsjNRCY'})
download.GetContentFile('sonar.csv')

# %%
ls
# Out:
# sample_data/  sonar.csv

# %% [markdown]
# ## Do some magic below! ;)

# %%
import pandas as pd
df = pd.read_csv('sonar.csv',header=None)

# %%
df.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
#        ...
# 56    float64
# 57    float64
# 58    float64
# 59    float64
# 60     object
# Length: 61, dtype: object

# %%
# Split the data into features and labels
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Normalize the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# Encode the labels
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
y = encoder.fit_transform(y)

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train a binary neural network classifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical


# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 63ms/step - loss: 0.6561 - accuracy: 0.6061 - val_loss: 0.6768 - val_accuracy: 0.5882
# Epoch 2/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5702 - accuracy: 0.7273 - val_loss: 0.6362 - val_accuracy: 0.7059
# Epoch 3/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5169 - accuracy: 0.7955 - val_loss: 0.5950 - val_accuracy: 0.7059
# Epoch 4/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4763 - accuracy: 0.8561 - val_loss: 0.5595 - val_accuracy: 0.7647
# Epoch 5/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4383 - accuracy: 0.8561 - val_loss: 0.5365 - val_accuracy: 0.7647
# Epoch 6/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4067 - accuracy: 0.8864 - val_loss: 0.5142 - val_accuracy: 0.7647
# Epoch 7/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3802 - accuracy: 0.8864 - val_loss: 0.4940 - val_accuracy: 0.7941
# Epoch 8/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3520 - accuracy: 0.8939 - val_loss: 0.4791 - val_accuracy: 0.7647
# Epoch 9/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3265 - accuracy: 0.8864 - val_loss: 0.4669 - val_accuracy: 0.7647
# Epoch 10/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3028 - accuracy: 0.8939 - val_loss: 0.4526 - val_accuracy: 0.7941
# Epoch 11/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2811 - accuracy: 0.9015 - val_loss: 0.4410 - val_accuracy: 0.7941
# Epoch 12/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2605 - accuracy: 0.9015 - val_loss: 0.4335 - val_accuracy: 0.7647
# Epoch 13/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2404 - accuracy: 0.9318 - val_loss: 0.4227 - val_accuracy: 0.7647
# Epoch 14/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2213 - accuracy: 0.9470 - val_loss: 0.4069 - val_accuracy: 0.8235
# Epoch 15/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2045 - accuracy: 0.9470 - val_loss: 0.3817 - val_accuracy: 0.7941
# Epoch 16/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1877 - accuracy: 0.9621 - val_loss: 0.3712 - val_accuracy: 0.7941
# Epoch 17/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1754 - accuracy: 0.9621 - val_loss: 0.3689 - val_accuracy: 0.8235
# Epoch 18/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1632 - accuracy: 0.9697 - val_loss: 0.3663 - val_accuracy: 0.7941
# Epoch 19/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1498 - accuracy: 0.9848 - val_loss: 0.3661 - val_accuracy: 0.7941
# Epoch 20/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1383 - accuracy: 0.9924 - val_loss: 0.3665 - val_accuracy: 0.7941
# Epoch 21/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1261 - accuracy: 0.9924 - val_loss: 0.3612 - val_accuracy: 0.7941
# Epoch 22/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1166 - accuracy: 0.9924 - val_loss: 0.3557 - val_accuracy: 0.7941
# Epoch 23/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1072 - accuracy: 0.9924 - val_loss: 0.3521 - val_accuracy: 0.8235
# Epoch 24/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0987 - accuracy: 0.9924 - val_loss: 0.3507 - val_accuracy: 0.8235
# Epoch 25/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0902 - accuracy: 0.9924 - val_loss: 0.3425 - val_accuracy: 0.8529
# Epoch 26/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0836 - accuracy: 0.9924 - val_loss: 0.3411 - val_accuracy: 0.8529
# Epoch 27/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0765 - accuracy: 0.9924 - val_loss: 0.3448 - val_accuracy: 0.8529
# Epoch 28/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0700 - accuracy: 0.9924 - val_loss: 0.3457 - val_accuracy: 0.8529
# Epoch 29/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0654 - accuracy: 1.0000 - val_loss: 0.3512 - val_accuracy: 0.8235
# Epoch 30/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 0.3437 - val_accuracy: 0.8235
# Epoch 31/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.8235
# Epoch 32/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.3334 - val_accuracy: 0.8235
# Epoch 33/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0453 - accuracy: 1.0000 - val_loss: 0.3257 - val_accuracy: 0.8529
# Epoch 34/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0414 - accuracy: 1.0000 - val_loss: 0.3252 - val_accuracy: 0.8529
# Epoch 35/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.3224 - val_accuracy: 0.8529
# Epoch 36/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.3201 - val_accuracy: 0.8529
# Epoch 37/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.8529
# Epoch 38/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.3089 - val_accuracy: 0.8529
# Epoch 39/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.3027 - val_accuracy: 0.8824
# Epoch 40/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.3067 - val_accuracy: 0.8529
# Epoch 41/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.3015 - val_accuracy: 0.8529
# Epoch 42/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.2943 - val_accuracy: 0.8529
# Epoch 43/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.2878 - val_accuracy: 0.8529
# Epoch 44/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.2798 - val_accuracy: 0.8529
# Epoch 45/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 0.8529
# Epoch 46/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.8824
# Epoch 47/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.2811 - val_accuracy: 0.8529
# Epoch 48/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.8529
# Epoch 49/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.2950 - val_accuracy: 0.8529
# Epoch 50/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.2914 - val_accuracy: 0.8824
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3097 - accuracy: 0.8810
# Test Accuracy: 0.8810
