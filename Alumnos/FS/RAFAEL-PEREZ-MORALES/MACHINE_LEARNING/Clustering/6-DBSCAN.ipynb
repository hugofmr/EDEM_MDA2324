# %%
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-d02e84e5-b335-4336-902b-657ce6c8265a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d02e84e5-b335-4336-902b-657ce6c8265a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Import the libraries
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn import metrics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import .csv file and convert it to a DataFrame object
df = pd.read_csv("Mall_Customers.csv")

# %%
df.head()

# %%
df.describe()

# %%
print(df.info())

# %%
# chequear si hay muestral null en el dataset
# Out:
# False

# %%
# eliminar CustomerID y Genre

# %% [markdown]
# ## Medir bien las distancias
#
# Como tenemos datos numéricos y categóricos hay que crear un métodod de distancia de Gower para ajustar bien.

# %%
# Tarea: normalizar características

# %%
from sklearn.neighbors import NearestNeighbors
# Encontrar las distancias k
k = 8
# Tarea: implementar el k vecinos para determinar eps
# Probad con varios k...

# %%
# Ordenar las distancias, CUIDADO con los axis

# Ordenamos las muestras de menor a mayor, mirar los ejes


# Realizar la media de cada muestra

# %%
# Graficar las distancias k de las medias de cada punto

# %%
# Entrenar DBSCAN, elegid eps acorde a la gráfica anterior


dbscan.fit(X)

# %%
# Obtener el Silhouette Score

# %%
# ¿Qué indican las muestras -1?
dbscan.labels_

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
# Contar cuantas muestras hay por cluster

# %%
# Concatenar ambos dataframes

# %%
plt.scatter(X[:,0], X[:,1])

# %%
# Plotear las dos primeras características con los colores de los labels
# ¿Qué os parecen los outliers?

# %%
df_final.head()

# %%
# Obtener un dataframe por cada cluster

# %% [markdown]
# # Análisis de los clúster
